# %%
import pandas as pd

url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
pokeaman = pd.read_csv(url) 
pokeaman
import statsmodels.formula.api as smf

model1_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation) + Q("Sp. Def"):C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") * C(Generation)', data=pokeaman)

model2_fit = model2_spec.fit()
model2_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     15.27
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           3.50e-27
# Time:                        21:10:42   Log-Likelihood:                -3649.4
# No. Observations:                 800   AIC:                             7323.
# Df Residuals:                     788   BIC:                             7379.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Q4: R-squared (17.6% Variability Explained): The R-squared value of 17.6% indicates that only a small portion of the variance in the dependent variable (HP) is explained by the predictors (Sp. Def, Generation, and their interaction terms) in your model. This implies that there are likely other factors influencing HP that are not included in this model, meaning it is not a comprehensive or fully predictive model of HP.
#
# Large Coefficients with Strong Statistical Significance: The large coefficients and strong statistical evidence against the null hypothesis for some terms suggest that, within the context of this model, changes in Sp. Def, Generation, or the interactions are indeed associated with changes in HP. However, this association does not necessarily imply a strong explanatory power across the full range of variability in HP — it only indicates that there is a detectable, statistically significant relationship within the confines of what this model assesses.

# %% [markdown]
# Q7:
# From Model 3,4 to Model 5: Model 5 further expands on this by adding additional predictors and some categorical variables to more thoroughly capture complex patterns in HP. This increases explanatory power by incorporating more potentially relevant characteristics without overwhelming interaction terms.
# From Model 5 to Model 6: The goal here is parsimony—retaining only those predictors with demonstrated importance. This simplifies the model while maintaining predictive accuracy.
# From Model 6 to Model 7: Scaling and centering are applied to numeric variables to improve stability, particularly helpful in a model with high interactions, thereby reducing multicollinearity and enhancing robustness.

# %% [markdown]
# Q9: The code examines how well the regression models predict Pokémon HP for different subsets of the data based on generation. By splitting the data into groups (e.g., Generation 1 vs. Generation 6), we can see if the model trained on one group performs well when applied to a different generation. This is important because it helps us understand whether the model can generalize to unseen Pokémon or if it's overfitting the data it was trained on. High in-sample R-squared values mean a good fit, but the real test is whether the model can predict accurately for different generations of Pokémon, which is reflected in the out-of-sample R-squared.

# %% [markdown]
# Chatbot history link: https://chatgpt.com/share/67367824-f344-800a-bc4f-dc48b6067749
